# %% [markdown]
# <a href="https://colab.research.google.com/github/Preranakh/Advanced-NLP/blob/main/Prep%20Word%20Vectors%20For%20Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # word2vec: How To Prep Word Vectors For Modeling

# %% [markdown]
# ### Train Our Own Model

# %%
# Read in the data, clean it, split it into train and test sets, and then train a word2vec model
import gensim
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', 100)

messages = pd.read_csv('spam.csv', encoding='latin-1')
messages = messages.drop(labels = ["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis = 1)
messages.columns = ["label", "text"]


messages['text_clean'] = messages['text'].apply(lambda x: gensim.utils.simple_preprocess(x))
X_train, X_test, y_train, y_test = train_test_split(messages['text_clean'],
                                                    messages['label'], test_size=0.2)

w2v_model = gensim.models.Word2Vec(X_train,
                                   size=100,
                                   window=5,
                                   min_count=2)

# %% [markdown]
# ### Prep Word Vectors

# %%
# Generate a list of words the word2vec model learned word vectors for
# these are all the words that appear in the training data at least twice
w2v_model.wv.index2word
# Out:
# ['to',
#  'you',
#  'the',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'it',
#  'for',
#  'your',
#  'of',
#  'that',
#  'have',
#  'call',
#  'on',
#  'are',
#  'now',
#  'can',
#  'so',
#  'but',
#  'not',
#  'at',
#  'or',
#  'get',
#  'do',
#  'if',
#  'we',
#  'be',
#  'will',
#  'no',
#  'with',
#  'just',
#  'ur',
#  'this',
#  'up',
#  'lt',
#  'gt',
#  'when',
#  'from',
#  'go',
#  'ok',
#  'how',
#  'free',
#  'what',
#  'all',
#  'out',
#  'know',
#  'll',
#  'then',
#  'got',
#  'am',
#  'good',
#  'like',
#  'there',
#  'time',
#  'day',
#  'its',
#  'was',
#  'come',
#  'he',
#  'only',
#  'want',
#  'text',
#  'love',
#  'send',
#  'by',
#  'as',
#  'txt',
#  'lor',
#  'one',
#  'going',
#  'about',
#  'don',
#  'home',
#  'stop',
#  'today',
#  'need',
#  'sorry',
#  'still',
#  'see',
#  'she',
#  'back',
#  'reply',
#  'our',
#  'da',
#  'new',
#  'dont',
#  'mobile',
#  'phone',
#  'they',
#  'tell',
#  'think',
#  'take',
#  'ì_',
#  'her',
#  'night',
#  'pls',
#  'later',
#  'where',
#  'week',
#  'hi',
#  'any',
#  'please',
#  'oh',
#  'here',
#  'been',
#  'well',
#  'did',
#  'dear',
#  'some',
#  'has',
#  'who',
#  'msg',
#  're',
#  'wat',
#  'much',
#  'way',
#  'an',
#  'too',
#  'great',
#  'more',
#  'him',
#  'hope',
#  'happy',
#  'had',
#  'claim',
#  'make',
#  'give',
#  'www',
#  'message',
#  'number',
#  'hey',
#  'work',
#  'them',
#  'after',
#  'doing',
#  'tomorrow',
#  've',
#  'prize',
#  'ask',
#  'yes',
#  'right',
#  'meet',
#  'said',
#  'im',
#  'why',
#  'won',
#  'already',
#  'last',
#  'amp',
#  'really',
#  'life',
#  'would',
#  'very',
#  'nokia',
#  'win',
#  'com',
#  'say',
#  'should',
#  'lol',
#  'cos',
#  'babe',
#  'also',
#  'cash',
#  'find',
#  'yeah',
#  'anything',
#  'pick',
#  'every',
#  'morning',
#  'wait',
#  'care',
#  'uk',
#  'miss',
#  'over',
#  'sent',
#  'buy',
#  'let',
#  'before',
#  'keep',
#  'sure',
#  'thing',
#  'first',
#  'min',
#  'us',
#  'thanks',
#  'contact',
#  'were',
#  'went',
#  'cant',
#  'gonna',
#  'wan',
#  'around',
#  'again',
#  'help',
#  'could',
#  'next',
#  'feel',
#  'down',
#  'which',
#  'tonight',
#  'someone',
#  'off',
#  'late',
#  'sms',
#  'urgent',
#  'tone',
#  'his',
#  'haha',
#  'nice',
#  'service',
#  'per',
#  'many',
#  'something',
#  'even',
#  'gud',
#  'same',
#  'dun',
#  'sleep',
#  'fine',
#  'place',
#  'mins',
#  'box',
#  'ya',
#  'customer',
#  'leave',
#  'told',
#  'soon',
#  'may',
#  'waiting',
#  'done',
#  'coming',
#  'name',
#  'money',
#  'wish',
#  'days',
#  'pm',
#  'chat',
#  'thk',
#  'getting',
#  'st',
#  'ìï',
#  'things',
#  'didn',
#  'hello',
#  'other',
#  'co',
#  'best',
#  'always',
#  'friends',
#  'friend',
#  'stuff',
#  'year',
#  'talk',
#  'few',
#  'guaranteed',
#  'ppm',
#  'heart',
#  'yet',
#  'use',
#  'yup',
#  'smile',
#  'draw',
#  'being',
#  'lunch',
#  'check',
#  'thats',
#  'try',
#  'holiday',
#  'ready',
#  'thought',
#  'dat',
#  'live',
#  'ill',
#  'cool',
#  'line',
#  'special',
#  'awarded',
#  'another',
#  'bit',
#  'never',
#  'job',
#  'class',
#  'mind',
#  'end',
#  'finish',
#  'people',
#  'than',
#  'chance',
#  'word',
#  'cs',
#  'lar',
#  'receive',
#  'into',
#  'half',
#  'trying',
#  'car',
#  'better',
#  'meeting',
#  'real',
#  'sir',
#  'man',
#  'pobox',
#  'god',
#  'yo',
#  'problem',
#  'world',
#  'dinner',
#  'lot',
#  'because',
#  'latest',
#  'account',
#  'guys',
#  'shit',
#  'video',
#  'ah',
#  'house',
#  'jus',
#  'having',
#  'eat',
#  'wk',
#  'dunno',
#  'big',
#  'enjoy',
#  'room',
#  'guess',
#  'might',
#  'person',
#  'long',
#  'weekend',
#  'th',
#  'wanna',
#  'play',
#  'camera',
#  'month',
#  'bed',
#  'start',
#  'called',
#  'probably',
#  'liao',
#  'two',
#  'orange',
#  'nothing',
#  'landline',
#  'watch',
#  'ever',
#  'didnt',
#  'bt',
#  'network',
#  'put',
#  'cost',
#  'xxx',
#  'shopping',
#  'princess',
#  'luv',
#  'thanx',
#  'speak',
#  'nite',
#  'early',
#  'fun',
#  'maybe',
#  'left',
#  'remember',
#  'bad',
#  'den',
#  'actually',
#  'once',
#  'pa',
#  'minutes',
#  'plan',
#  'wont',
#  'birthday',
#  'look',
#  'entry',
#  'working',
#  'dad',
#  'girl',
#  'sweet',
#  'aight',
#  'age',
#  'selected',
#  'tmr',
#  'hrs',
#  'means',
#  'hour',
#  'watching',
#  'made',
#  'shows',
#  'til',
#  'missing',
#  'nd',
#  'rate',
#  'sat',
#  'forgot',
#  'tones',
#  'mail',
#  'texts',
#  'years',
#  'school',
#  'xmas',
#  'enough',
#  'pay',
#  'does',
#  'price',
#  'ringtone',
#  'juz',
#  'tv',
#  'quite',
#  'bus',
#  'times',
#  'award',
#  'leh',
#  'hav',
#  'between',
#  'hear',
#  'away',
#  'little',
#  'without',
#  'pain',
#  'dis',
#  'join',
#  'true',
#  'most',
#  'fuck',
#  'haf',
#  'apply',
#  'anyway',
#  'boy',
#  'shop',
#  'po',
#  'asked',
#  'delivery',
#  'wif',
#  'offer',
#  'missed',
#  'details',
#  'makes',
#  'everything',
#  'weekly',
#  'those',
#  'baby',
#  'shall',
#  'kiss',
#  'part',
#  'guy',
#  'collect',
#  'able',
#  'hair',
#  'stay',
#  'decimal',
#  'show',
#  'tried',
#  'wake',
#  'xx',
#  'gift',
#  'while',
#  'town',
#  'says',
#  'though',
#  'plz',
#  'valid',
#  'wot',
#  'came',
#  'since',
#  'important',
#  'calls',
#  'office',
#  'yourself',
#  'gr',
#  'messages',
#  'evening',
#  'goin',
#  'wants',
#  'reach',
#  'drive',
#  'collection',
#  'abt',
#  'question',
#  'easy',
#  'run',
#  'code',
#  'until',
#  'mob',
#  'these',
#  'net',
#  'wanted',
#  'lei',
#  'okay',
#  'update',
#  'face',
#  'till',
#  'making',
#  'brother',
#  'yesterday',
#  'optout',
#  'wen',
#  'bring',
#  'afternoon',
#  'feeling',
#  'family',
#  'hot',
#  'both',
#  'goes',
#  'plus',
#  'haven',
#  'oso',
#  'thank',
#  'wife',
#  'sexy',
#  'wid',
#  'busy',
#  'book',
#  'thinking',
#  'de',
#  'either',
#  'coz',
#  'friendship',
#  'todays',
#  'colour',
#  'driving',
#  'calling',
#  'charge',
#  'music',
#  'chikku',
#  'must',
#  'sch',
#  'movie',
#  'smiling',
#  'havent',
#  'pic',
#  'looking',
#  'worry',
#  'leaving',
#  'yours',
#  'words',
#  'eve',
#  'awesome',
#  'story',
#  'trip',
#  'available',
#  'top',
#  'drop',
#  'suite',
#  'dreams',
#  'vouchers',
#  'mean',
#  'hours',
#  'forget',
#  'smoke',
#  'answer',
#  'walk',
#  'mths',
#  'comes',
#  'address',
#  'saw',
#  'finished',
#  'started',
#  'auction',
#  'row',
#  'hurt',
#  'simple',
#  'sad',
#  'alright',
#  'id',
#  'bonus',
#  'attempt',
#  'angry',
#  'http',
#  'gd',
#  'nt',
#  'unsubscribe',
#  'happen',
#  'food',
#  'search',
#  'set',
#  'noe',
#  'sae',
#  'change',
#  'test',
#  'bored',
#  'anyone',
#  'else',
#  'choose',
#  'dude',
#  'online',
#  'doesn',
#  'congrats',
#  'order',
#  'national',
#  'okie',
#  'card',
#  'email',
#  'tho',
#  'sleeping',
#  'old',
#  'yr',
#  'pics',
#  'frnd',
#  'finally',
#  'takes',
#  'company',
#  'opt',
#  'drink',
#  'sis',
#  'second',
#  'await',
#  'game',
#  'games',
#  'tot',
#  'bout',
#  'lose',
#  'huh',
#  'type',
#  'head',
#  'hl',
#  'beautiful',
#  'rite',
#  'lets',
#  'cause',
#  'ring',
#  'ha',
#  'girls',
#  'mine',
#  'open',
#  'everyone',
#  'neva',
#  'parents',
#  'club',
#  'took',
#  'double',
#  'worth',
#  'lesson',
#  'touch',
#  'aft',
#  'mom',
#  'wil',
#  'hard',
#  'lucky',
#  'full',
#  'post',
#  'sounds',
#  'fri',
#  'anytime',
#  'alone',
#  'lands',
#  'minute',
#  'ard',
#  'date',
#  'far',
#  'wkly',
#  'poly',
#  'together',
#  'hows',
#  'light',
#  'least',
#  'camcorder',
#  'sex',
#  'rs',
#  'support',
#  'mobileupd',
#  'pub',
#  'hee',
#  'fucking',
#  'case',
#  'believe',
#  'their',
#  'mrng',
#  'found',
#  'sun',
#  'final',
#  'land',
#  'meant',
#  'download',
#  'treat',
#  'visit',
#  'fast',
#  'crazy',
#  'info',
#  'darlin',
#  'services',
#  'each',
#  'congratulations',
#  'log',
#  'hand',
#  'outside',
#  'carlos',
#  'blue',
#  'project',
#  'pounds',
#  'tomo',
#  'smth',
#  'player',
#  'gbp',
#  'operator',
#  'wrong',
#  'saying',
#  'gone',
#  'dating',
#  'content',
#  'ltd',
#  'whatever',
#  'college',
#  'motorola',
#  'quiz',
#  'offers',
#  'hungry',
#  'mum',
#  'goodmorning',
#  'close',
#  'nope',
#  'months',
#  'side',
#  'cum',
#  'heard',
#  'father',
#  'mate',
#  'reading',
#  'seeing',
#  'boytoy',
#  'used',
#  'earlier',
#  'private',
#  'yar',
#  'points',
#  'winner',
#  'happened',
#  'fr',
#  'lovely',
#  'gas',
#  'die',
#  'nyt',
#  'bank',
#  'rental',
#  'ass',
#  'loving',
#  'darren',
#  'whole',
#  'knw',
#  'frm',
#  'saturday',
#  'party',
#  'credit',
#  'sister',
#  'kind',
#  'mates',
#  'rest',
#  'voucher',
#  'lost',
#  'decided',
#  'jay',
#  'tired',
#  'msgs',
#  'txts',
#  'wq',
#  'welcome',
#  'dogging',
#  'met',
#  'break',
#  'savamob',
#  'india',
#  'dnt',
#  'ago',
#  'telling',
#  'sea',
#  'friday',
#  'joy',
#  'ans',
#  'park',
#  'hmm',
#  'questions',
#  'within',
#  'ac',
#  'mah',
#  'thinks',
#  'mu',
#  'hold',
#  'valued',
#  'wow',
#  'lots',
#  'happiness',
#  'extra',
#  'weeks',
#  'chennai',
#  'wit',
#  'oredi',
#  'mayb',
#  'song',
#  'û_',
#  'picking',
#  'information',
#  'taking',
#  'wasn',
#  'frnds',
#  'caller',
#  'gym',
#  'poor',
#  'comp',
#  'write',
#  'numbers',
#  'isn',
#  'drugs',
#  'whats',
#  'abiola',
#  'ugh',
#  'pretty',
#  'fancy',
#  'rply',
#  'unlimited',
#  'ten',
#  'red',
#  'match',
#  'store',
#  'freemsg',
#  'reward',
#  'gotta',
#  'complimentary',
#  'eh',
#  'move',
#  'yep',
#  'course',
#  'tc',
#  'sk',
#  'invited',
#  'cut',
#  'statement',
#  'secret',
#  'reveal',
#  'asking',
#  'fone',
#  'sending',
#  'listen',
#  'muz',
#  'doin',
#  'news',
#  'hg',
#  'stupid',
#  'yrs',
#  'wonder',
#  'read',
#  'tel',
#  'felt',
#  'wonderful',
#  'press',
#  'comin',
#  'wana',
#  'difficult',
#  'bb',
#  'na',
#  'sunday',
#  'needs',
#  'luck',
#  'plans',
#  'charged',
#  'gn',
#  'empty',
#  'grins',
#  'sick',
#  'bathe',
#  'ringtones',
#  'rates',
#  'wondering',
#  'small',
#  'bslvyl',
#  'silent',
#  'mode',
#  'hoping',
#  'swing',
#  'wine',
#  'la',
#  'area',
#  'summer',
#  'deep',
#  'forwarded',
#  'valentine',
#  'slowly',
#  'glad',
#  'gets',
#  'cd',
#  'john',
#  'whenever',
#  'il',
#  'reason',
#  'correct',
#  'knows',
#  'tickets',
#  'march',
#  'using',
#  'hmmm',
#  'save',
#  'fact',
#  'gettin',
#  'laugh',
#  'txting',
#  'identifier',
#  'expires',
#  'lect',
#  'paper',
#  'wap',
#  'sony',
#  'em',
#  'lovable',
#  'ni',
#  'christmas',
#  'terms',
#  'mm',
#  'spend',
#  'through',
#  'bath',
#  'truth',
#  'ends',
#  'none',
#  'enter',
#  'nobody',
#  'phones',
#  'entered',
#  'surprise',
#  'remove',
#  'uncle',
#  'usf',
#  'oops',
#  'loved',
#  'seems',
#  'direct',
#  'ge',
#  'reached',
#  'less',
#  'others',
#  'gal',
#  'somebody',
#  'monday',
#  'hit',
#  'snow',
#  'wc',
#  'talking',
#  'std',
#  'clean',
#  'balance',
#  'currently',
#  'sort',
#  'tonite',
#  'wishing',
#  'semester',
#  'reaching',
#  'exam',
#  'comuk',
#  'charity',
#  'dream',
#  'ipod',
#  'england',
#  'trust',
#  'thinkin',
#  'normal',
#  'nigeria',
#  'pass',
#  'slept',
#  'goodnight',
#  'rock',
#  'orchard',
#  'bluetooth',
#  'wiv',
#  'matches',
#  'hw',
#  'bold',
#  'stand',
#  'lazy',
#  'asap',
#  'children',
#  'self',
#  'doctor',
#  'loads',
#  'water',
#  'urself',
#  'worries',
#  'woke',
#  'honey',
#  'worried',
#  'askd',
#  'digital',
#  'own',
#  'representative',
#  'pete',
#  'un',
#  'admirer',
#  'rent',
#  'shower',
#  'ice',
#  'feels',
#  'loan',
#  'ts',
#  'rain',
#  'kate',
#  'immediately',
#  'disturb',
#  'men',
#  'noon',
#  'eyes',
#  'fantastic',
#  'leaves',
#  'couple',
#  ...]

# %%
# Generate aggregated sentence vectors based on the word vectors for each word in the sentence
w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index2word])
                     for ls in X_test])
# Out:
# <ipython-input-3-11a8d2e02a06>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   w2v_vect = np.array([np.array([w2v_model.wv[i] for i in ls if i in w2v_model.wv.index2word])

# %%
# Why is the length of the sentence different than the length of the sentence vector?
for i, v in enumerate(w2v_vect):
    print(len(X_test.iloc[i]), len(v))
# Out:
#
# 8 5
# 6 6
# 11 8
# 9 9
# 9 9
# 15 13
# 7 7
# 13 13
# 16 13
# 29 29
# 28 18
# 30 30
# 77 62
# 25 21
# 22 22
# 10 8
# 9 9
# 31 29
# 33 31
# 5 5
# 14 12
# 12 11
# 12 11
# 23 22
# 6 6
# 4 4
# 32 31
# 16 13
# 60 60
# 11 10
# 8 7
# 25 20
# 6 6
# 5 5
# 8 8
# 10 8
# 17 16
# 13 13
# 9 8
# 4 3
# 13 11
# 5 4
# 10 9
# 24 23
# 6 6
# 24 21
# 24 24
# 20 20
# 15 15
# 5 4
# 6 5
# 35 28
# 5 4
# 10 9
# 7 6
# 5 5
# 21 20
# 6 6
# 5 5
# 11 9
# 8 6
# 22 21
# 25 25
# 15 15
# 31 27
# 12 10
# 24 20
# 29 28
# 27 24
# 5 5
# 6 6
# 23 22
# 15 15
# 6 6
# 6 5
# 28 25
# 10 10
# 9 9
# 30 27
# 15 14
# 15 13
# 17 14
# 6 6
# 9 9
# 7 7
# 16 16
# 25 25
# 13 13
# 19 19
# 20 20
# 15 15
# 10 8
# 17 11
# 6 5
# 32 31

# %%
# Compute sentence vectors by averaging the word vectors for the words contained in the sentence
w2v_vect_avg = []

for vect in w2v_vect:
    if len(vect)!=0:
        w2v_vect_avg.append(vect.mean(axis=0))
    else:
        w2v_vect_avg.append(np.zeros(100))

# %%
# Are our sentence vector lengths consistent?
#check if the lenght of vector is consistent or not
#Now the machine learning model will see 100 features for each text message it sees
for i, v in enumerate(w2v_vect_avg):
    print(len(X_test.iloc[i]), len(v))
# Out:
# 26 100
# 8 100
# 18 100
# 7 100
# 18 100
# 13 100
# 5 100
# 15 100
# 19 100
# 6 100
# 13 100
# 24 100
# 11 100
# 8 100
# 35 100
# 7 100
# 15 100
# 20 100
# 6 100
# 26 100
# 22 100
# 7 100
# 34 100
# 27 100
# 8 100
# 14 100
# 8 100
# 9 100
# 12 100
# 5 100
# 26 100
# 9 100
# 3 100
# 19 100
# 36 100
# 101 100
# 23 100
# 6 100
# 4 100
# 5 100
# 18 100
# 10 100
# 9 100
# 9 100
# 11 100
# 15 100
# 7 100
# 5 100
# 14 100
# 9 100
# 10 100
# 28 100
# 19 100
# 14 100
# 9 100
# 6 100
# 6 100
# 7 100
# 2 100
# 13 100
# 9 100
# 13 100
# 30 100
# 14 100
# 12 100
# 24 100
# 0 100
# 9 100
# 5 100
# 12 100
# 5 100
# 6 100
# 5 100
# 7 100
# 13 100
# 9 100
# 23 100
# 7 100
# 5 100
# 12 100
# 7 100
# 27 100
# 4 100
# 16 100
# 19 100
# 11 100
# 14 100
# 27 100
# 29 100
# 2 100
# 10 100
# 11 100
# 12 100
# 11 100
# 18 100
# 74 100
# 10 100
# 5 100
# 25 100
# 16 100
# 34 100
# 8 100
# 11 100
# 10 100
# 25 100
# 6 100
# 25 100
# 21 100
# 16 100
# 6 100
# 6 100
# 29 100
# 13 100
# 18 100
# 13 100
# 9 100
# 11 100
# 4 100
# 7 100
# 5 100
# 26 100
# 4 100
# 5 100
# 7 100
# 12 100
# 22 100
# 10 100
# 14 100
# 9 100
# 8 100
# 25 100
# 17 100
# 28 100
# 11 100
# 4 100
# 7 100
# 22 100
# 31 100
# 24 100
# 14 100
# 42 100
# 8 100
# 29 100
# 13 100
# 25 100
# 11 100
# 30 100
# 6 100
# 4 100
# 12 100
# 17 100
# 6 100
# 11 100
# 11 100
# 8 100
# 7 100
# 9 100
# 3 100
# 12 100
# 5 100
# 5 100
# 27 100
# 10 100
# 16 100
# 6 100
# 4 100
# 26 100
# 10 100
# 6 100
# 29 100
# 10 100
# 8 100
# 6 100
# 5 100
# 1 100
# 7 100
# 8 100
# 8 100
# 20 100
# 24 100
# 21 100
# 9 100
# 9 100
# 12 100
# 20 100
# 17 100
# 7 100
# 20 100
# 5 100
# 20 100
# 18 100
# 17 100
# 9 100
# 5 100
# 21 100
# 24 100
# 8 100
# 8 100
# 10 100
# 5 100
# 15 100
# 23 100
# 30 100
# 15 100
# 24 100
# 8 100
# 21 100
# 17 100
# 6 100
# 8 100
# 19 100
# 2 100
# 23 100
# 5 100
# 20 100
# 22 100
# 28 100
# 5 100
# 4 100
# 12 100
# 10 100
# 16 100
# 38 100
# 9 100
# 21 100
# 9 100
# 4 100
# 3 100
# 8 100
# 5 100
# 4 100
# 7 100
# 30 100
# 13 100
# 23 100
# 16 100
# 27 100
# 27 100
# 32 100
# 24 100
# 7 100
# 5 100
# 4 100
# 17 100
# 7 100
# 15 100
# 25 100
# 7 100
# 24 100
# 7 100
# 8 100
# 19 100
# 15 100
# 22 100
# 20 100
# 5 100
# 9 100
# 29 100
# 9 100
# 5 100
# 8 100
# 27 100
# 16 100
# 4 100
# 6 100
# 15 100
# 4 100
# 23 100
# 15 100
# 11 100
# 22 100
# 12 100
# 5 100
# 44 100
# 16 100
# 7 100
# 6 100
# 7 100
# 10 100
# 30 100
# 9 100
# 26 100
# 8 100
# 10 100
# 10 100
# 27 100
# 13 100
# 9 100
# 19 100
# 9 100
# 10 100
# 13 100
# 7 100
# 21 100
# 4 100
# 19 100
# 27 100
# 9 100
# 18 100
# 16 100
# 21 100
# 51 100
# 8 100
# 28 100
# 9 100
# 14 100
# 12 100
# 27 100
# 5 100
# 11 100
# 3 100
# 9 100
# 8 100
# 15 100
# 27 100
# 6 100
# 20 100
# 2 100
# 8 100
# 9 100
# 6 100
# 7 100
# 24 100
# 22 100
# 25 100
# 5 100
# 5 100
# 15 100
# 24 100
# 14 100
# 9 100
# 11 100
# 9 100
# 21 100
# 31 100
# 7 100
# 24 100
# 12 100
# 22 100
# 22 100
# 29 100
# 24 100
# 6 100
# 25 100
# 20 100
# 27 100
# 23 100
# 9 100
# 13 100
# 5 100
# 14 100
# 5 100
# 17 100
# 13 100
# 12 100
# 29 100
# 14 100
# 15 100
# 6 100
# 16 100
# 4 100
# 21 100
# 16 100
# 25 100
# 9 100
# 9 100
# 8 100
# 16 100
# 8 100
# 11 100
# 10 100
# 10 100
# 12 100
# 9 100
# 21 100
# 4 100
# 8 100
# 23 100
# 26 100
# 8 100
# 6 100
# 18 100
# 21 100
# 8 100
# 16 100
# 5 100
# 14 100
# 5 100
# 11 100
# 12 100
# 4 100
# 10 100
# 12 100
# 28 100
# 15 100
# 10 100
# 26 100
# 8 100
# 10 100
# 14 100
# 6 100
# 9 100
# 29 100
# 25 100
# 5 100
# 6 100
# 10 100
# 24 100
# 5 100
# 5 100
# 5 100
# 22 100
# 10 100
# 6 100
# 16 100
# 4 100
# 5 100
# 16 100
# 6 100
# 11 100
# 9 100
# 21 100
# 6 100
# 5 100
# 4 100
# 14 100
# 1 100
# 9 100
# 5 100
# 9 100
# 11 100
# 15 100
# 4 100
# 5 100
# 27 100
# 18 100
# 16 100
# 26 100
# 11 100
# 10 100
# 2 100
# 7 100
# 7 100
# 24 100
# 31 100
# 17 100
# 11 100
# 36 100
# 19 100
# 4 100
# 17 100
# 7 100
# 1 100
# 28 100
# 8 100
# 16 100
# 6 100
# 29 100
# 11 100
# 27 100
# 6 100
# 21 100
# 19 100
# 21 100
# 16 100
# 14 100
# 27 100
# 6 100
# 33 100
# 13 100
# 23 100
# 24 100
# 8 100
# 13 100
# 10 100
# 26 100
# 25 100
# 16 100
# 24 100
# 10 100
# 8 100
# 25 100
# 19 100
# 24 100
# 7 100
# 11 100
# 10 100
# 15 100
# 6 100
# 30 100
# 10 100
# 25 100
# 10 100
# 11 100
# 6 100
# 16 100
# 28 100
# 27 100
# 6 100
# 1 100
# 9 100
# 31 100
# 7 100
# 8 100
# 21 100
# 12 100
# 5 100
# 23 100
# 8 100
# 24 100
# 29 100
# 12 100
# 7 100
# 10 100
# 4 100
# 22 100
# 6 100
# 5 100
# 35 100
# 21 100
# 9 100
# 1 100
# 12 100
# 5 100
# 10 100
# 22 100
# 7 100
# 22 100
# 22 100
# 11 100
# 18 100
# 5 100
# 7 100
# 5 100
# 11 100
# 11 100
# 4 100
# 16 100
# 10 100
# 21 100
# 9 100
# 22 100
# 4 100
# 4 100
# 6 100
# 4 100
# 8 100
# 18 100
# 6 100
# 4 100
# 9 100
# 26 100
# 2 100
# 28 100
# 30 100
# 9 100
# 9 100
# 16 100
# 5 100
# 19 100
# 11 100
# 7 100
# 9 100
# 8 100
# 13 100
# 1 100
# 6 100
# 14 100
# 31 100
# 6 100
# 21 100
# 1 100
# 18 100
# 11 100
# 8 100
# 1 100
# 30 100
# 6 100
# 21 100
# 22 100
# 49 100
# 8 100
# 17 100
# 4 100
# 10 100
# 25 100
# 22 100
# 6 100
# 6 100
# 13 100
# 28 100
# 4 100
# 23 100
# 8 100
# 9 100
# 2 100
# 5 100
# 16 100
# 15 100
# 11 100
# 16 100
# 29 100
# 26 100
# 7 100
# 4 100
# 30 100
# 12 100
# 7 100
# 1 100
# 5 100
# 12 100
# 18 100
# 15 100
# 6 100
# 23 100
# 13 100
# 7 100
# 19 100
# 20 100
# 15 100
# 45 100
# 29 100
# 37 100
# 5 100
# 8 100
# 12 100
# 14 100
# 9 100
# 4 100
# 27 100
# 9 100
# 2 100
# 13 100
# 5 100
# 28 100
# 73 100
# 10 100
# 25 100
# 21 100
# 23 100
# 16 100
# 26 100
# 22 100
# 5 100
# 22 100
# 25 100
# 8 100
# 17 100
# 4 100
# 25 100
# 4 100
# 9 100
# 5 100
# 4 100
# 14 100
# 7 100
# 22 100
# 24 100
# 6 100
# 18 100
# 6 100
# 10 100
# 14 100
# 7 100
# 2 100
# 12 100
# 13 100
# 24 100
# 23 100
# 18 100
# 8 100
# 17 100
# 14 100
# 5 100
# 10 100
# 23 100
# 7 100
# 60 100
# 20 100
# 17 100
# 9 100
# 7 100
# 7 100
# 9 100
# 3 100
# 7 100
# 3 100
# 22 100
# 8 100
# 18 100
# 55 100
# 32 100
# 6 100
# 6 100
# 8 100
# 20 100
# 3 100
# 33 100
# 6 100
# 20 100
# 22 100
# 25 100
# 16 100
# 21 100
# 13 100
# 3 100
# 24 100
# 6 100
# 7 100
# 16 100
# 17 100
# 18 100
# 20 100
# 20 100
# 7 100
# 5 100
# 11 100
# 12 100
# 11 100
# 29 100
# 39 100
# 6 100
# 16 100
# 8 100
# 16 100
# 7 100
# 12 100
# 5 100
# 4 100
# 11 100
# 6 100
# 31 100
# 5 100
# 7 100
# 5 100
# 21 100
# 5 100
# 17 100
# 12 100
# 6 100
# 36 100
# 7 100
# 7 100
# 1 100
# 17 100
# 27 100
# 9 100
# 5 100
# 15 100
# 23 100
# 18 100
# 5 100
# 5 100
# 5 100
# 7 100
# 11 100
# 24 100
# 17 100
# 28 100
# 15 100
# 8 100
# 24 100
# 22 100
# 14 100
# 3 100
# 24 100
# 14 100
# 6 100
# 13 100
# 24 100
# 18 100
# 11 100
# 19 100
# 8 100
# 14 100
# 6 100
# 18 100
# 7 100
# 4 100
# 7 100
# 10 100
# 11 100
# 18 100
# 15 100
# 21 100
# 31 100
# 10 100
# 44 100
# 38 100
# 5 100
# 8 100
# 5 100
# 4 100
# 6 100
# 12 100
# 6 100
# 4 100
# 7 100
# 13 100
# 5 100
# 14 100
# 10 100
# 23 100
# 23 100
# 6 100
# 20 100
# 21 100
# 14 100
# 6 100
# 15 100
# 1 100
# 6 100
# 12 100
# 5 100
# 17 100
# 7 100
# 25 100
# 14 100
# 4 100
# 7 100
# 9 100
# 6 100
# 10 100
# 3 100
# 10 100
# 6 100
# 25 100
# 18 100
# 11 100
# 4 100
# 26 100
# 14 100
# 23 100
# 20 100
# 11 100
# 23 100
# 29 100
# 10 100
# 4 100
# 1 100
# 31 100
# 6 100
# 5 100
# 5 100
# 26 100
# 15 100
# 16 100
# 13 100
# 11 100
# 26 100
# 9 100
# 23 100
# 11 100
# 14 100
# 16 100
# 21 100
# 20 100
# 34 100
# 27 100
# 9 100
# 20 100
# 36 100
# 5 100
# 14 100
# 3 100
# 8 100
# 8 100
# 5 100
# 12 100
# 5 100
# 5 100
# 5 100
# 31 100
# 18 100
# 6 100
# 16 100
# 6 100
# 8 100
# 12 100
# 1 100
# 16 100
# 6 100
# 6 100
# 16 100
# 21 100
# 6 100
# 8 100
# 5 100
# 20 100
# 3 100
# 13 100
# 22 100
# 15 100
# 19 100
# 2 100
# 20 100
# 25 100
# 7 100
# 4 100
# 62 100
# 23 100
# 12 100
# 16 100
# 5 100
# 6 100
# 21 100
# 17 100
# 9 100
# 25 100
# 18 100
# 7 100
# 11 100
# 5 100
# 30 100
# 8 100
# 20 100
# 14 100
# 8 100
# 11 100
# 27 100
# 4 100
# 4 100
# 10 100
# 10 100
# 7 100
# 4 100
# 33 100
# 13 100
# 17 100
# 8 100
# 6 100
# 9 100
# 7 100
# 12 100
# 7 100
# 18 100
# 18 100
# 30 100
# 16 100
# 7 100
# 6 100
# 25 100
# 9 100
# 4 100
# 7 100
# 23 100
# 30 100
# 8 100
# 7 100
# 7 100
# 8 100
# 17 100
# 7 100
# 4 100
# 13 100
# 1 100
# 5 100
# 21 100
# 40 100
# 3 100
# 23 100
# 5 100
# 3 100
# 12 100
# 15 100
# 17 100
# 9 100
# 23 100
# 16 100
# 8 100
# 4 100
# 46 100
# 17 100
# 26 100
# 25 100
# 13 100
# 10 100
# 23 100
# 7 100
# 5 100
# 9 100
# 7 100
# 9 100
# 9 100
# 14 100
# 22 100
# 11 100
# 8 100
# 5 100
# 16 100
# 15 100
# 26 100
# 9 100
# 17 100
# 8 100
# 12 100
# 5 100
# 25 100
# 61 100
# 11 100
# 12 100
# 5 100
# 14 100
# 21 100
# 7 100
# 10 100
# 6 100
# 8 100
# 4 100
# 19 100
# 4 100
# 12 100
# 15 100
# 23 100
# 4 100
# 10 100
# 6 100
# 20 100
# 9 100
# 22 100
# 8 100
# 6 100
# 11 100
# 9 100
# 9 100
# 15 100
# 7 100
# 13 100
# 16 100
# 29 100
# 28 100
# 30 100
# 77 100
# 25 100
# 22 100
# 10 100
# 9 100
# 31 100
# 33 100
# 5 100
# 14 100
# 12 100
# 12 100
# 23 100
# 6 100
# 4 100
# 32 100
# 16 100
# 60 100
# 11 100
# 8 100
# 25 100
# 6 100
# 5 100
# 8 100
# 10 100
# 17 100
# 13 100
# 9 100
# 4 100
# 13 100
# 5 100
# 10 100
# 24 100
# 6 100
# 24 100
# 24 100
# 20 100
# 15 100
# 5 100
# 6 100
# 35 100
# 5 100
# 10 100
# 7 100
# 5 100
# 21 100
# 6 100
# 5 100
# 11 100
# 8 100
# 22 100
# 25 100
# 15 100
# 31 100
# 12 100
# 24 100
# 29 100
# 27 100
# 5 100
# 6 100
# 23 100
# 15 100
# 6 100
# 6 100
# 28 100
# 10 100
# 9 100
# 30 100
# 15 100
# 15 100
# 17 100
# 6 100
# 9 100
# 7 100
# 16 100
# 25 100
# 13 100
# 19 100
# 20 100
# 15 100
# 10 100
# 17 100
# 6 100
# 32 100
